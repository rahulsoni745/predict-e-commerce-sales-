# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ecommerce_data.csv')
df.head()
# Out:
#    Unnamed: 0                                              Title  Price  \
# 0           0  ACEMAGIC 15.6\n                               ...  £299.
# 1           1  15.6" Full HD Laptop - 8GB RAM 512GB SSD, Wind...  £279.
# 2           2  Acer Aspire Go 15 AG15-31P Laptop - Intel Core...  £298.
# 3           3  ACEMAGIC Laptop Computer 15.6 inch - Quad-Core...  £289.
# 4           4  ACEMAGIC 15.6 inch FHD Laptop Computer - Quad-...  £299.
#
#        RRP  Rating  Reviews  Purchases Past Month Charges Delivery Time  \
# 0  £459.99     4.3     24.0                   NaN  £12.25    Tue, 6 May
# 1  £349.99     4.7    215.0                 300.0  £11.61    Tue, 6 May
# 2  £354.00     4.4     86.0                 100.0     NaN           NaN
# 3  £439.99     4.5     56.0                  50.0     NaN           NaN
# 4  £459.99     4.3     24.0                  50.0  £12.25    Tue, 6 May
#
#          ASIN                                       Product Link
# 0  B0DR2FWCDL  https://www.amazon.co.uk/sspa/click?ie=UTF8&sp...
# 1  B0DT9XFCRB  https://www.amazon.co.uk/sspa/click?ie=UTF8&sp...
# 2         NaN  https://www.amazon.co.uk/Acer-Aspire-AG15-31P-...
# 3         NaN  https://www.amazon.co.uk/sspa/click?ie=UTF8&sp...
# 4  B0DR2FWCDL  https://www.amazon.co.uk/sspa/click?ie=UTF8&sp...

# %%
columns_to_clean = ['Price', 'RRP', 'Charges']
df[columns_to_clean] = df[columns_to_clean].replace({'£': '', ',': ''}, regex=True)
df[columns_to_clean] = df[columns_to_clean].apply(pd.to_numeric, errors='coerce')

# %%
df = df.drop(columns=['Unnamed: 0','Title','ASIN','Product Link','Delivery Time'])
df.head()
# Out:
#    Price     RRP  Rating  Reviews  Purchases Past Month  Charges
# 0  299.0  459.99     4.3     24.0                   NaN    12.25
# 1  279.0  349.99     4.7    215.0                 300.0    11.61
# 2  298.0  354.00     4.4     86.0                 100.0      NaN
# 3  289.0  439.99     4.5     56.0                  50.0      NaN
# 4  299.0  459.99     4.3     24.0                  50.0    12.25

# %%
df['Charges'] = df['Charges'].fillna(0)
df['Purchases Past Month'] = df['Purchases Past Month'].fillna(0)

# %%
df.head()
# Out:
#    Price     RRP  Rating  Reviews  Purchases Past Month  Charges
# 0  299.0  459.99     4.3     24.0                   0.0    12.25
# 1  279.0  349.99     4.7    215.0                 300.0    11.61
# 2  298.0  354.00     4.4     86.0                 100.0     0.00
# 3  289.0  439.99     4.5     56.0                  50.0     0.00
# 4  299.0  459.99     4.3     24.0                  50.0    12.25

# %%
df.isnull().sum()
# Out:
# Price                    33
# RRP                     182
# Rating                   29
# Reviews                  36
# Purchases Past Month      0
# Charges                   0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()
df['Price'] = si.fit_transform(df[['Price']])
df['RRP'] = si.fit_transform(df[['RRP']])
df['Rating'] = si.fit_transform(df[['Rating']])
df['Reviews'] = si.fit_transform(df[['Reviews']])

# %%
df.isnull().sum()
# Out:
# Price                   0
# RRP                     0
# Rating                  0
# Reviews                 0
# Purchases Past Month    0
# Charges                 0
# dtype: int64

# %%
# !pip install matplotlib
# !pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
purchase_counts = df['Purchases Past Month'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(purchase_counts, labels=purchase_counts.index, autopct='%1.1f%%')
plt.title('Purchases Distribution in the Past Month')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Price'], kde=True, color='skyblue')
plt.title("Count on the basis of Price Distribution")
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
x = df.drop(columns = 'Price')
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor()
}

model_performance = {}

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    r2 = r2_score(y_test, y_pred)
    model_performance[name] = r2

print(model_performance)
# Out:
# {'Linear Regression': 0.9053479333285529, 'Decision Tree': 0.8007194004652989, 'Random Forest': 0.9047314648184304}

# %%
best_model = max(model_performance, key=lambda x: model_performance[x])
print(f"The best model is: {best_model} with R^2 score of {model_performance[best_model]}")
# Out:
# The best model is: Linear Regression with R^2 score of 0.9053479333285529

# %%
# Use only 'Rating' for visualization
x_rating = df[['Rating']]  
y_price = df['Price']

# Fit the best model again using Rating only
lin_model = LinearRegression()
lin_model.fit(x_rating, y_price)
y_pred_line = lin_model.predict(x_rating)

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(x_rating, y_price, color='skyblue', label='Data Points')
plt.plot(x_rating, y_pred_line, color='red',label='Regression Line')
plt.xlabel("Rating")
plt.ylabel("Price (£)")
plt.title("Linear Regression: Rating vs Price")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

model = RandomForestRegressor()

# %%
param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [5, 10, 15, 20, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
    }

# %%
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15, 20, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='r2')

# %%
best_tuned_model = grid_search.best_estimator_

# %%
y_pred = best_tuned_model.predict(x_test)
r2 = r2_score(y_test, y_pred)
print(f"Best Tuned Model R^2 Score: {r2}")
# Out:
# Best Tuned Model R^2 Score: 0.9295235471999965

# %%
feature_importances = pd.Series(best_tuned_model.feature_importances_, index=x.columns)
feature_importances.sort_values().plot(kind='barh', figsize=(8,6))
plt.title('Feature Importances (After Hypertuning)')
plt.show()
